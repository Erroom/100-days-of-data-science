# %% [markdown]
# Create a NumPy ndarray Object

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %% [markdown]
# NumPy Array Indexing

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])

print(arr[0])
# Out:
# 1
