# %%
from sqlalchemy import create_engine,text
user='root'
password=''
host='localhost'
port='3306'
database='Practice_SqlAlchemy'
database_url =f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"
engine=create_engine(database_url,echo=True)
try:
    with engine.connect() as connection:
        result = connection.execute(text("Select 1"))
        print("\nConnection successful! Result of 'SELECT 1':")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# 2026-06-04 13:09:49,791 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-06-04 13:09:49,792 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-04 13:09:49,793 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-06-04 13:09:49,794 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-04 13:09:49,795 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-06-04 13:09:49,796 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-04 13:09:49,798 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-04 13:09:49,798 INFO sqlalchemy.engine.Engine Select 1
# 2026-06-04 13:09:49,799 INFO sqlalchemy.engine.Engine [generated in 0.00134s] {}
#
# Connection successful! Result of 'SELECT 1':
# 2026-06-04 13:09:49,800 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
from sqlalchemy import MetaData, Table, Column, Integer, String
metadata=MetaData()
Students=Table(
    'students',metadata,
    Column('id',Integer,primary_key=True),
    Column('name',String(100)),
    Column('Lastname',String(100))
)
metadata.create_all(engine)
# Out:
# 2026-06-04 13:09:57,981 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-04 13:09:57,982 INFO sqlalchemy.engine.Engine DESCRIBE `practice_sqlalchemy`.`students`
# 2026-06-04 13:09:57,983 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-04 13:09:58,030 INFO sqlalchemy.engine.Engine COMMIT

# %%
#For insert data into table
with engine.connect() as connection:
    ins=Students.insert().values(id=1,name='John',Lastname='Doe')
    connection.execute(ins)
    connection.commit()
# Out:
# 2026-06-04 13:15:32,123 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-04 13:15:32,124 INFO sqlalchemy.engine.Engine INSERT INTO students (id, name, `Lastname`) VALUES (%(id)s, %(name)s, %(Lastname)s)
# 2026-06-04 13:15:32,125 INFO sqlalchemy.engine.Engine [generated in 0.00168s] {'id': 1, 'name': 'John', 'Lastname': 'Doe'}
# 2026-06-04 13:15:32,128 INFO sqlalchemy.engine.Engine COMMIT

# %%
ins=Students.insert().values(id=2,name="Raj",Lastname="Sharma")
